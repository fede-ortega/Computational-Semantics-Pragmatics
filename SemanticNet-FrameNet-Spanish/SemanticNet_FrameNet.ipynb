# %% [markdown]
# # Práctica FrameNet
#
# Federico Ortega Riba

# %% [markdown]
# ## Obtén el marco de las acciones tipo DAR de FrameNet en su versión inglesa

# %%
import nltk
nltk.download('framenet_v17')
# Out:
# [nltk_data] Downloading package framenet_v17 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/framenet_v17.zip.
# True

# %%
from pprint import pprint
from operator import itemgetter
from nltk.corpus import framenet as fn
from nltk.corpus.reader.framenet import PrettyList

# %%
frame = fn.frames('Giving')[0]

# %% [markdown]
# ## ¿Cuál es su ID?

# %%
print("Frame ID:", frame.ID)
# Out:
# Frame ID: 139

# %% [markdown]
# ## ¿Cuál es su nombre?

# %%
print("Frame Name:", frame.name)
# Out:
# Frame Name: Giving

# %%
print("Frame Definition:", frame.definition)
# Out:
# Frame Definition: A Donor transfers a Theme from a Donor to a Recipient.  This frame includes only actions that are initiated by the Donor (the one that starts out owning the Theme).  Sentences (even metaphorical ones) must meet the following entailments: the  Donor first has possession of the Theme.  Following the transfer the Donor no longer has the Theme and the Recipient does. 'Barney gave the beer to Moe.' '$300 was endowed to the university to build a new performing arts building.'

# %% [markdown]
# ## ¿Has acertado en los argumentos nucleares (core)?

# %%
pprint(sorted([x for x in x.FE]))
# Out:
# ['Circumstances',
#  'Depictive',
#  'Donor',
#  'Explanation',
#  'Imposed_purpose',
#  'Manner',
#  'Means',
#  'Period_of_iterations',
#  'Place',
#  'Purpose',
#  'Recipient',
#  'Theme',
#  'Time']

# %%
print("Core Elements:", frame.FE)
# Out:
# Core Elements: [Donor] frame element (1052): Donor
#     of Giving(139)
# [definition]
#   The person that begins in possession of the Theme and causes it
#   to be in the possession of the Recipient .
# [abbrev] Donor
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Recipient] frame element (1053): Recipient
#     of Giving(139)
# [definition]
#   The entity that ends up in possession of the Theme.
# [abbrev] Rec
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Theme] frame element (1054): Theme
#     of Giving(139)
# [definition]
#   The object that changes ownership.
# [abbrev] Thm
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Physical_object(68)
#
# [Place] frame element (1680): Place
#     of Giving(139)
# [definition]
#   The Place where the Donor gives the Theme to the Recipient.
# [abbrev] Place
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Locative_relation(182)
#
# [Explanation] frame element (1681): Explanation
#     of Giving(139)
# [definition]
#   The Explanation for which the Donor gives the Theme to the
#   Recipient.
# [abbrev] Exp
# [coreType] Extra-Thematic
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   State_of_affairs(177)
#
# [Time] frame element (1682): Time
#     of Giving(139)
# [definition]
#   The Time is when the Donor gives the Theme to the Recipient.
# [abbrev] Time
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Time(141)
#
# [Purpose] frame element (1719): Purpose
#     of Giving(139)
# [definition]
#   The Purpose for which the Donor gives the Theme to the Recipient.
# [abbrev] Purp
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   State_of_affairs(177)
#
# [Means] frame element (1732): Means
#     of Giving(139)
# [definition]
#   The Means by which the Donor gives the Theme to the Recipient.
# [abbrev] Mns
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   State_of_affairs(177)
#
# [Manner] frame element (3539): Manner
#     of Giving(139)
# [definition]
#   The Manner is the manner in which the Donor gives the Theme to
#   the Recipient.
# [abbrev] Man
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Manner(173)
#
# [Circumstances] frame element (3564): Circumstances
#     of Giving(139)
# [definition]
#   The Circumstances are the conditions under which the Theme is
#   given. 'I give my services free of charge.'
# [abbrev] cir
# [coreType] Extra-Thematic
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Imposed_purpose] frame element (4819): Imposed_purpose
#     of Giving(139)
# [definition]
#   The Recipient's intended purpose for the Theme. 'Please give this
#   list to the secretary for entry into the client database.'
# [abbrev] Imp
# [coreType] Extra-Thematic
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Depictive] frame element (11956): Depictive
#     of Giving(139)
# [definition]
#   A description of the Donor, Recipient, or Theme given
#   independently of the giving event per se.
# [abbrev] dep
# [coreType] Extra-Thematic
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Period_of_iterations] frame element (13069): Period_of_iterations
#     of Giving(139)
# [definition]
#   The length of time from when the event denoted by the target
#   began to be repeated to when it stopped.
# [abbrev]
# [coreType] Extra-Thematic
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>

# %% [markdown]
# Sí he acertado los argumentos nucleares, aunque en mi caso, al argumento "Theme" lo he llamado "Donado".

# %% [markdown]
# ## ¿Cuáles son los lemas verbales que se corresponden con este marco este marco de casos?

# %%
len(frame.lexUnit)
# Out:
# 26

# %%
print("Lexical Units:", frame.lexUnit)
# Out:
# Lexical Units: [give.v] lexical unit (4344): give.v
#
# [definition]
#   COD: freely transfer the possession of; cause to receive or have.
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] give/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu4344.xml
#
# [subCorpus] 31 subcorpora
#   V-429-s20-lcoll-generously, V-429-s20-lcoll-quickly,
#   V-429-s20-rcoll-her, V-429-s20-rcoll-him, V-429-s20-rcoll-
#   me, V-429-s20-rcoll-money, V-429-s20-rcoll-painting,
#   V-429-s20-rcoll-sum, V-429-s20-rcoll-support,
#   V-429-s20-rcoll-them, V-429-s20-rcoll-you, V-530-s20-np-
#   vpto, V-550-s20-np-np, V-570-s20-np-ppfor, V-570-s20-np-
#   ppon, V-570-s20-np-ppto, V-620-s20-np-ppother, V-650-s20-np-
#   pother, V-660-s20-trans-simple, V-670-s20-pass-by,
#   V-680-s20-pass, V-690-s20-trans-other, V-730-s20-ppfor,
#   V-730-s20-ppon, V-730-s20-ppto, V-780-s20-ppother,
#   V-810-s20-pother, V-880-s20-intrans-simple,
#   V-890-s20-intrans-adverb, V-900-s20-other, manually-added
#
# [exemplars] 49 sentences across all subcorpora
#
# [donate.v] lexical unit (5344): donate.v
#
# [definition]
#   COD: give (money or goods) for a good cause
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] donate/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu5344.xml
#
# [subCorpus] 26 subcorpora
#   V-429-s20-lcoll-freely, V-429-s20-lcoll-generously,
#   V-429-s20-lcoll-kindly, V-429-s20-lcoll-recently,
#   V-429-s20-rcoll-blood, V-429-s20-rcoll-item,
#   V-429-s20-rcoll-money, V-429-s20-rcoll-organ, V-530-s20-np-
#   vpto, V-570-s20-np-ppfor, V-570-s20-np-ppfrom, V-570-s20-np-
#   ppto, V-620-s20-np-ppother, V-650-s20-np-pother,
#   V-660-s20-trans-simple, V-670-s20-pass-by, V-680-s20-pass,
#   V-690-s20-trans-other, V-730-s20-ppfor, V-730-s20-ppto,
#   V-780-s20-ppother, V-810-s20-pother, V-880-s20-intrans-
#   simple, V-890-s20-intrans-adverb, V-900-s20-other, manually-
#   added
#
# [exemplars] 57 sentences across all subcorpora
#
# [donation.n] lexical unit (5345): donation.n
#
# [definition]
#   COD: something that is given to a charity, especially a sum of
#   money.
#
# [frame] Giving(139)
#
# [POS] N
#
# [status] Finished_Initial
#
# [lexemes] donation/N
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu5345.xml
#
# [subCorpus] 13 subcorpora
#   02-Wcash,card-T-(1), 03-Wfood,blood,organ-T-(1),
#   04-Wcharity,charitable-T-(1), 05-Wyour,my,his-T-(1),
#   06-XPng-gen-NP-T-(1), 07-T-PPfrom-(1), 08-T-PPto-(1),
#   09-T-PPOF-(1), 10-T-PPfor-(1), 11-T-PPtowards-(1), manually-
#   added, other-matched-(1), other-unmatched-(1)
#
# [exemplars] 19 sentences across all subcorpora
#
# [donor.n] lexical unit (5346): donor.n
#
# [definition]
#   COD: a person who donates something.
#
# [frame] Giving(139)
#
# [POS] N
#
# [status] Finished_Initial
#
# [lexemes] donor/N
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu5346.xml
#
# [subCorpus] 14 subcorpora
#   01-NP-Wbe,become-T-(1), 02-T-Wbe-NP-(1),
#   03-Wblood,organ,kidney-T-(1), 04-XPng-gen-NP-T-(1),
#   05-T-PPto-(1), 06-T-PPOF-(1), 07-Waid-T-(1),
#   08-T-Wpledge,give,finance-(1),
#   09-T-Wcountry,nation,agency-(1),
#   10-Wanonymous,major,western-T-(1), 11-Wappeal-T-(1),
#   manually-added, other-matched-(1), other-unmatched-(1)
#
# [exemplars] 15 sentences across all subcorpora
#
# [foist.v] lexical unit (5347): foist.v
#
# [definition]
#   COD: impose an unwelcome or unnecessary person or thing on.
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] foist/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu5347.xml
#
# [subCorpus] 4 subcorpora
#   01-T-(1), V-001-all, other-matched-(1), other-unmatched-(1)
#
# [exemplars] 8 sentences across all subcorpora
#
# [endow.v] lexical unit (5348): endow.v
#
# [definition]
#   COD: give or bequeath an income or property to.
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] endow/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu5348.xml
#
# [subCorpus] 23 subcorpora
#   V-429-s20-lcoll-generously, V-429-s20-lcoll-liberally,
#   V-429-s20-rcoll-castle, V-429-s20-rcoll-charity,
#   V-429-s20-rcoll-church, V-429-s20-rcoll-institution,
#   V-429-s20-rcoll-land, V-429-s20-rcoll-museum,
#   V-429-s20-rcoll-property, V-570-s20-np-ppin, V-570-s20-np-
#   ppwith, V-620-s20-np-ppother, V-650-s20-np-pother,
#   V-660-s20-trans-simple, V-670-s20-pass-by, V-680-s20-pass,
#   V-690-s20-trans-other, V-730-s20-ppin, V-730-s20-ppwith,
#   V-780-s20-ppother, V-810-s20-pother, V-880-s20-intrans-
#   simple, V-900-s20-other
#
# [exemplars] 9 sentences across all subcorpora
#
# [fob off.v] lexical unit (5353): fob off.v
#
# [definition]
#   COD: give (something inferior) to.
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Insufficient_Attestations
#
# [lexemes] fob/V off/ADV
#
# [semTypes] 1 semantic types
#   Negative_judgment(14)
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu5353.xml
#
# [subCorpus] 1 subcorpora
#   V-001-all
#
# [exemplars] 0 sentences across all subcorpora
#
# [give out.v] lexical unit (5361): give out.v
#
# [definition]
#   FN: give freely (to a large number of recipients).
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] give/V out/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu5361.xml
#
# [subCorpus] 14 subcorpora
#   V-660-s20-trans-simple, V-670-s20-pass-by, V-680-s100-pass,
#   V-680-s20-pass, V-690-s20-trans-other, V-820-s100-avpout,
#   V-829-s100-pass-avpout, V-830-s100-avpout-np, V-840-s100-np-
#   avpout, V-870-s100-avpother, V-880-s20-intrans-simple,
#   V-890-s20-intrans-adverb, V-900-s20-other, manually-added
#
# [exemplars] 20 sentences across all subcorpora
#
# [hand over.v] lexical unit (5369): hand over.v
#
# [definition]
#   FN: hand to someone else
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] hand/V over/ADV
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu5369.xml
#
# [subCorpus] 8 subcorpora
#   01-T-NP-(2), 02-T-Wover-NP-PP-(2), 03-T-NP-Wover-PPto-(2),
#   04-T-Wover-PPto,for-(2), 05-T-Wover-PPby-(2),
#   07-T-XPtime-(2), other-matched-(2), other-unmatched-(2)
#
# [exemplars] 27 sentences across all subcorpora
#
# [hand out.v] lexical unit (5370): hand out.v
#
# [definition]
#   COD: distribute something among a group of people
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] hand/V out/ADV
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu5370.xml
#
# [subCorpus] 13 subcorpora
#   V-660-s20-trans-simple, V-670-s20-pass-by, V-680-s100-pass,
#   V-680-s20-pass, V-690-s20-trans-other, V-820-s100-avpout,
#   V-829-s100-pass-avpout, V-830-s100-avpout-np, V-840-s100-np-
#   avpout, V-870-s100-avpother, V-880-s20-intrans-simple,
#   V-890-s20-intrans-adverb, V-900-s20-other
#
# [exemplars] 27 sentences across all subcorpora
#
# [gift.v] lexical unit (5371): gift.v
#
# [definition]
#   COD: give as a gift, especially formally.
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] gift/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu5371.xml
#
# [subCorpus] 4 subcorpora
#   01-T-(1), V-001-all, other-matched-(1), other-unmatched-(1)
#
# [exemplars] 6 sentences across all subcorpora
#
# [gift.n] lexical unit (5372): gift.n
#
# [definition]
#   COD: a thing given willingly to someone without payment; a
#   present.
#
# [frame] Giving(139)
#
# [POS] N
#
# [status] Finished_Initial
#
# [lexemes] gift/N
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu5372.xml
#
# [subCorpus] 16 subcorpora
#   01-XPng-gen-T-(1), 02-Wpos-T-(1), 03-T-PPto-(1),
#   04-T-PPfrom-(1), 05-T-PPfor-(1), 06-T-PPby,with,between-(1),
#   07-T-PPOF-(1), 08-Wgive,offer-T-(1),
#   09-Waccept,receive,get-T-(1), 10-Wsend,bring,chose-(1),
#   11-T-PP-(1), 12-Wwedding,retirement,farewell-T-(1),
#   13-Wgreat,small,free-T-(1), manually-added, other-
#   matched-(1), other-unmatched-(1)
#
# [exemplars] 30 sentences across all subcorpora
#
# [pass out.v] lexical unit (5374): pass out.v
#
# [definition]
#   FN: distribute something among a group
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] pass/V out/ADV
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu5374.xml
#
# [subCorpus] 13 subcorpora
#   V-660-s20-trans-simple, V-670-s20-pass-by, V-680-s100-pass,
#   V-680-s20-pass, V-690-s20-trans-other, V-820-s100-avpout,
#   V-829-s100-pass-avpout, V-830-s100-avpout-np, V-840-s100-np-
#   avpout, V-870-s100-avpother, V-880-s20-intrans-simple,
#   V-890-s20-intrans-adverb, V-900-s20-other
#
# [exemplars] 4 sentences across all subcorpora
#
# [bequeath.v] lexical unit (7214): bequeath.v
#
# [definition]
#   COD: leave (property) to a person or other beneficiary by a will.
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] bequeath/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu7214.xml
#
# [subCorpus] 16 subcorpora
#   V-429-s20-lcoll-lovingly, V-429-s20-rcoll-collection,
#   V-429-s20-rcoll-museum, V-429-s20-rcoll-university,
#   V-570-s20-np-ppfor, V-570-s20-np-ppto, V-620-s20-np-ppother,
#   V-660-s20-trans-simple, V-670-s20-pass-by, V-680-s20-pass,
#   V-690-s20-trans-other, V-730-s20-ppto, V-780-s20-ppother,
#   V-880-s20-intrans-simple, V-890-s20-intrans-adverb,
#   V-900-s20-other
#
# [exemplars] 23 sentences across all subcorpora
#
# [treat.v] lexical unit (8033): treat.v
#
# [definition]
#   COD: provide someone with (food, drink, or entertainment) at
#   one's expense
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] treat/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu8033.xml
#
# [subCorpus] 5 subcorpora
#   04-T-NPyourself,herself,myself-(1),
#   05-T-NPdinner,lunch,dessert-(1), 06-T-NP-PPto-(1), other-
#   matched-(1), other-unmatched-(1)
#
# [exemplars] 13 sentences across all subcorpora
#
# [hand.v] lexical unit (8905): hand.v
#
# [definition]
#   COD: pick (something) up and give it to (someone).
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] hand/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu8905.xml
#
# [subCorpus] 15 subcorpora
#   01-T-PPto-(1), 02-T-PPfrom-(1), 03-T-PPfor-(1), 04-T-NP-
#   PPto-(1), 05-T-NP-PPfrom-(1), 06-T-PPinto,off-(1),
#   07-T-PPin,on,at-(1), 08-T-NPperson,human-(1), 09-T-NP-(1),
#   10-T-NPletter,key,paper-(1), 11-T-XPplace,time-(1),
#   12-T-Wbecause,order,with-(1), manually-added, other-
#   matched-(1), other-unmatched-(1)
#
# [exemplars] 37 sentences across all subcorpora
#
# [hand in.v] lexical unit (9138): hand in.v
#
# [definition]
#   FN: give to an authority in accordance with obligation
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] hand/V in/PREP
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu9138.xml
#
# [subCorpus] 12 subcorpora
#   01-T-Win-(1), 01-Tvvn-Win-PPby-(2),
#   02-T-NPpaper,essay,notice-Win-(1), 03-T-Win-
#   NPpaper,essay,notice-(1), 04-T-Win-PP-(1), 05-T-Win-
#   PPpolice,officer,clerk-(1), 06-T-Win-PPtime-(1),
#   08-NPstudent-T-Win-(1), other-matched-(1), other-
#   matched-(2), other-unmatched-(1), other-unmatched-(2)
#
# [exemplars] 31 sentences across all subcorpora
#
# [contribute.v] lexical unit (12046): contribute.v
#
# [definition]
#   COD: give in order to help achieve or provide something.
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] contribute/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu12046.xml
#
# [subCorpus] 9 subcorpora
#   01-T-Warticle,sum,essay-(1), 02-T-Wshare,money,insight-(1),
#   03-Wmember,government,department-T-(1), 04-NP-T-NP-PPto-(1),
#   05-NP-T-NP-(1), 06-NP-T-PPto-(1), manually-added, other-
#   matched-(1), other-unmatched-(1)
#
# [exemplars] 24 sentences across all subcorpora
#
# [contribution.n] lexical unit (12047): contribution.n
#
# [definition]
#   FN: something that is given towards an effort or cause
#
# [frame] Giving(139)
#
# [POS] N
#
# [status] Created
#
# [lexemes] contribution/N
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu12047.xml
#
# [subCorpus] 1 subcorpora
#   manually-added
#
# [exemplars] 6 sentences across all subcorpora
#
# [charity.n] lexical unit (14695): charity.n
#
# [definition]
#   FN: a gift to or the act of giving to another
#
# [frame] Giving(139)
#
# [POS] N
#
# [status] Created
#
# [lexemes] charity/N
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu14695.xml
#
# [subCorpus] 0 subcorpora
#
#
# [exemplars] 0 sentences across all subcorpora
#
# [volunteer.v] lexical unit (15057): volunteer.v
#
# [definition]
#   FN: give something to a recipient in need
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Created
#
# [lexemes] volunteer/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu15057.xml
#
# [subCorpus] 0 subcorpora
#
#
# [exemplars] 0 sentences across all subcorpora
#
# [will.v] lexical unit (15059): will.v
#
# [definition]
#   FN: bequeath to someone according to one's written will
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Created
#
# [lexemes] will/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu15059.xml
#
# [subCorpus] 0 subcorpora
#
#
# [exemplars] 0 sentences across all subcorpora
#
# [leave.v] lexical unit (15099): leave.v
#
# [definition]
#   FN: bequeath
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] leave/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu15099.xml
#
# [subCorpus] 8 subcorpora
#   01-subject-(1), 02-passive-(2), 03-her+us+me+him+them-(2),
#   03-other-unmatched-(1), 03-will+husband-(3), 04-other-
#   matched-(2), 05-other-unmatched-(3), manually-added
#
# [exemplars] 11 sentences across all subcorpora
#
# [advance.v] lexical unit (15102): advance.v
#
# [definition]
#   FN: give earlier than scheduled
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Created
#
# [lexemes] advance/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu15102.xml
#
# [subCorpus] 0 subcorpora
#
#
# [exemplars] 0 sentences across all subcorpora
#
# [confer (upon).v] lexical unit (18516): confer (upon).v
#
# [definition]
#   FN: provide (something beneficial, us. a property); NB: only
#   usable when some aspect of the situation (the entity conferred or
#   the recipient) is abstract.
#
# [frame] Giving(139)
#
# [POS] V
#
# [status] Created
#
# [lexemes] confer/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu18516.xml
#
# [subCorpus] 0 subcorpora
#
#
# [exemplars] 0 sentences across all subcorpora
#
# [bequest.n] lexical unit (18517): bequest.n
#
# [definition]
#   FN: entity given by a deceased person upon their death.
#
# [frame] Giving(139)
#
# [POS] N
#
# [status] Created
#
# [lexemes] bequest/N
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu18517.xml
#
# [subCorpus] 0 subcorpora
#
#
# [exemplars] 0 sentences across all subcorpora

# %%
import re

# %%
import io
from contextlib import redirect_stdout

with io.StringIO() as captura_salida:
    with redirect_stdout(captura_salida):
        print("Lexical Units:", frame.lexUnit)

    frame_lexical_units = captura_salida.getvalue()

# %%
import re

# Expresión regular para extraer líneas con información sobre los verbos
expresion_regular = re.compile(r'\[([\w\s\(\)]*\.[vw]+)\] lexical unit \((\d+)\): ([\w\s\(\)]+)\.')

# Encontramos todas las coincidencias en el texto de frame_lexical_units
coincidencias = expresion_regular.findall(frame_lexical_units)

for i, match in enumerate(coincidencias, start=1):
    # Verificamos si el nombre termina en ".v" para distinguir entre verbos y sustantivos
    tipo = "Verbo" if match[0].endswith(".v") else "Nombre"
    print(f"Número: {i}, Tipo: {tipo}, ID: {match[1]}, Nombre: {match[2]}")
# Out:
# Número: 1, Tipo: Verbo, ID: 4344, Nombre: give
# Número: 2, Tipo: Verbo, ID: 5344, Nombre: donate
# Número: 3, Tipo: Verbo, ID: 5347, Nombre: foist
# Número: 4, Tipo: Verbo, ID: 5348, Nombre: endow
# Número: 5, Tipo: Verbo, ID: 5353, Nombre: fob off
# Número: 6, Tipo: Verbo, ID: 5361, Nombre: give out
# Número: 7, Tipo: Verbo, ID: 5369, Nombre: hand over
# Número: 8, Tipo: Verbo, ID: 5370, Nombre: hand out
# Número: 9, Tipo: Verbo, ID: 5371, Nombre: gift
# Número: 10, Tipo: Verbo, ID: 5374, Nombre: pass out
# Número: 11, Tipo: Verbo, ID: 7214, Nombre: bequeath
# Número: 12, Tipo: Verbo, ID: 8033, Nombre: treat
# Número: 13, Tipo: Verbo, ID: 8905, Nombre: hand
# Número: 14, Tipo: Verbo, ID: 9138, Nombre: hand in
# Número: 15, Tipo: Verbo, ID: 12046, Nombre: contribute
# Número: 16, Tipo: Verbo, ID: 15057, Nombre: volunteer
# Número: 17, Tipo: Verbo, ID: 15059, Nombre: will
# Número: 18, Tipo: Verbo, ID: 15099, Nombre: leave
# Número: 19, Tipo: Verbo, ID: 15102, Nombre: advance
# Número: 20, Tipo: Verbo, ID: 18516, Nombre: confer (upon)

# %% [markdown]
# ## Accede a los documentos marcados de este frame y busca dos ejemplos

# %% [markdown]
# * **Ejemplo 1**: The first prize was an Atlantic blue Rover 820 Fastback , most generously GIVEN by Sir Philip and Lady Harris.
# * **Ejemplo 2**: Katy and Jamie got ready very quickly and Mum GAVE each of them two wee spoons.
